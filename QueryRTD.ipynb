# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

queryRTD = pd.read_csv('queryRTDFebruary.csv') #funzione per leggere il file csv
queryRTD #per vedere il contenuto del DataFrame
# Out:
#             Created Date                Query  Total Results
# 0    2024-02-01 15:53:28        gruppo tenant             14
# 1    2024-02-01 15:53:05      tenant separati             12
# 2    2024-02-01 15:44:07  cronologia chiamate             16
# 3    2024-02-01 15:15:42         interruttori              5
# 4    2024-02-01 15:06:51         interruttori              5
# ..                   ...                  ...            ...
# 690  2024-01-03 09:31:26                trunk              7
# 691  2024-01-03 09:30:54                  lam              6
# 692  2024-01-03 09:20:52                speed              6
# 693  2024-01-03 09:20:47            numbering              0
# 694  2024-01-03 09:04:10             tls/srtp              7
#
# [695 rows x 3 columns]

# %%
# raggruppamento per query (quante volte ogni query appare)
query_counts = queryRTD['Query'].value_counts()

# prime N ricerche più frequenti
top_N = 15
top_queries = query_counts.head(top_N)

# dimensione del grafico
plt.figure(figsize=(10, 6))

# creazione grafico a barre
top_queries.plot(kind='bar', color='skyblue')

# etichette e titolo
plt.xlabel('Query')
plt.ylabel('Numero di Volte')
plt.title('Ricerche più effettuate')

# rotazione delle etichette sull'asse x
plt.xticks(rotation=45, ha='right')

# mostra il grafico
plt.show()

# %%
# Creazione nuovo DataFrame con query e quante volte appare la query
query_counts_df = pd.DataFrame({'Query': query_counts.index, 'Numero di volte': query_counts.values})

query_counts_df
# Out:
#                                  Query  Numero di volte
# 0                         provisioning               15
# 1                               webcti               13
# 2                                  ivr               12
# 3               instradamento dinamico               10
# 4                                 coda               10
# ..                                 ...              ...
# 427               unconditionalforward                1
# 428            modifica tasti funzione                1
# 429                           firewall                1
# 430  coda ritorna al livello superiore                1
# 431                           tls/srtp                1
#
# [432 rows x 2 columns]

# %%
query_counts_df.head(20)
# Out:
#                      Query  Numero di volte
# 0             provisioning               15
# 1                   webcti               13
# 2                      ivr               12
# 3   instradamento dinamico               10
# 4                     coda               10
# 5           interni remoti                9
# 6   registrazione chiamate                9
# 7                     code                8
# 8           casella vocale                7
# 9                 prelievo                7
# 10           instradamento                6
# 11                     api                6
# 12                    ldap                6
# 13                   nexus                5
# 14  trasferimento chiamata                5
# 15        controllo orario                5
# 16              encryption                5
# 17                 rubrica                5
# 18                   trunk                5
# 19                   hotel                5
